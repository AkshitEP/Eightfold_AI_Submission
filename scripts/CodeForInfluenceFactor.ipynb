# %%
import os
import openai
import json
import time
import concurrent.futures
from itertools import cycle
from threading import Lock

API_KEYS = [
"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"
]

# Settings for API limits
MAX_OPS_PER_SECOND = 30  # Max operations per second per API key
MAX_GLOBAL_OPS_PER_SECOND = 100  # Max global operations per second across all keys

# Shared resources for managing API keys and rate limiting
api_key_cycle = cycle(API_KEYS)  # Cycle through API keys
key_usage_counter = {key: 0 for key in API_KEYS}  # Track API key usage
lock = Lock()  # Ensure thread-safe access to shared resources

# OpenAI Client setup function
def get_openai_client(api_key):
    openai.api_key = api_key
    return openai.OpenAI(base_url="https://api.groq.com/openai/v1", api_key=api_key)

# %%
def llm_invoke(system_prompt, msg, api_key):
    """Invoke the LLM model using the provided API key with rate limiting."""
    max_retries = 5
    retry_delay = 5  # Base delay for retry (can be adjusted dynamically)
    
    for attempt in range(max_retries):
        try:
            # Apply rate-limiting logic
            with lock:
                # Ensure we don't exceed per-key and global limits
                while sum(key_usage_counter.values()) >= MAX_GLOBAL_OPS_PER_SECOND or key_usage_counter[api_key] >= MAX_OPS_PER_SECOND:
                    time.sleep(1)  # Wait 1 second and check again
                
                # Increment usage count for this key
                key_usage_counter[api_key] += 1
            
            client = get_openai_client(api_key)
            chat_completion = client.chat.completions.create(
                messages=[
                    {
                        "role": "system",
                        "content": system_prompt,
                    },
                    {
                        "role": "user",
                        "content": msg,
                    }
                ],
                model="llama-3.1-70b-versatile",
                temperature=0
            )
            
            return chat_completion.choices[0].message.content
        
        except openai.error.RateLimitError as e:
            if "Please try again in" in str(e):
                wait_time = int(e.response.json()['error']['message'].split('in')[1].split('s')[0].strip())
                print(f"Rate limit exceeded for API key: {api_key}. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                print(f"Rate limit error: {e}. Retrying in {retry_delay} seconds...")
                time.sleep(retry_delay)
        
        except Exception as e:
            print(f"Failed to invoke LLM with key {api_key}. Attempt {attempt + 1}/{max_retries}. Error: {e}")
            if attempt + 1 == max_retries:
                raise
            time.sleep(retry_delay)
        
        finally:
            with lock:
                # Reset the key usage after each request
                key_usage_counter[api_key] = max(0, key_usage_counter[api_key] - 1)

# %%
sys_msg = '''
You are given a resume, and an influence factor scoring system. Your task is to evaluate the resume based on the influence factor and provide a JSON output that includes the following:

1. **Influence Factor Score (1-10)**:
   - Evaluate the candidate's influence level based on the criteria below and provide a detailed breakdown of how the score was calculated:

**Scoring Criteria:**

   - **Job Role Level (Score: 1-5)**:
     - Executive Leadership (5 points): Roles like CEO, CFO, COO, CTO, President, Vice President.
     - Senior Management (4 points): Roles like Director, Senior Manager, Head of Department.
     - Middle Management (3 points): Roles like Manager, Team Lead, Supervisor.
     - Professional Staff (2 points): Roles like Senior Engineer, Senior Analyst, Specialist.
     - Entry-Level Positions (1 point): Roles like Junior Engineer, Assistant, Associate.

   - **Company Size and Influence (Score: 1-3)**:
     - Large Multinational Corporations or Highly Influential Organizations (3 points): Fortune 500 companies, major global brands, top-tier consultancies.
     - Medium-Sized Companies or Well-Known Organizations (2 points): Regional leaders, established mid-sized companies, recognized NGOs.
     - Small Companies or Lesser-Known Organizations (1 point): Startups, local businesses, small nonprofits.

   - **Experience and Tenure (Score: 0-2)**:
     - Extensive Experience (2 points): Over 10 years in their field or role.
     - Moderate Experience (1 point): 3 to 10 years in their field or role.
     - Limited Experience (0 points): Less than 3 years in their field or role.

2. **Calculation**:
   - Add up the points from each category to get the total Influence Factor Score out of 10.

3. Also mention the number of years of experience, if end date is present, current then take "2024" as the present year.
  - If not able to find the working experience store NaN

**Input Example:**
<Input>
{
    "details": {
        "job_history": [
            {
                "role_name": "Senior Project Manager",
                "company_level": "Large Corporation",
                "start_date": "01/2012",
                "end_date": "Present"
            }
        ],
        "education": [
            {
                "university": "XYZ University",
                "start_date": "09/2005",
                "end_date": "06/2009",
                "domain": "Business Administration",
                "level": "Bachelor's"
            }
        ]
    }
}
</Input>

**Expected Output:**
<Output>
{
  "working_experience" : 12
  "influence_factor_score": 9,
  "influence_factor_breakdown": {
    "job_role_level": 4,
    "company_size_and_influence": 3,
    "experience_and_tenure": 2
  },
  "notes": "The candidate's role as a Senior Project Manager at a large corporation, with over 10 years of experience, results in a high influence factor score."
}
</Output>
'''

# %%
def extract_text_with_keys(data, indent=0):
    """Recursively extract text from a JSON object, including keys."""
    text = ""
    if isinstance(data, dict):
        for key, value in data.items():
            text += '    ' * indent + f"{key}:\n"  # Indent for structure
            text += extract_text_with_keys(value, indent + 1)  # Recursively process value
    elif isinstance(data, list):
        for item in data:
            text += extract_text_with_keys(item, indent)
    elif isinstance(data, str):
        text += '    ' * indent + f"{data}\n"  # Indent for structure
    else:
        text += '    ' * indent + f"{data}\n"
    return text

def read_json_file(file_path):
    """Read a JSON file and return the extracted text with keys."""
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        return extract_text_with_keys(data).strip()  # Strip to remove extra newline at the end

# %%
def process_resume(resume_file_path, output_file_path, sys_msg):
    try:
        resume_content = read_json_file(resume_file_path)
        msg = f"Resume {resume_content}"

        api_key = next(api_key_cycle)
        raw_output = llm_invoke(sys_msg, msg, api_key)

        start_idx = raw_output.find("{")
        end_idx = raw_output.rfind("}") + 1
        json_output = raw_output[start_idx:end_idx]

        parsed_output = json.loads(json_output)

        with open(output_file_path, 'w', encoding='utf-8') as f:
            json.dump({"resume_file": os.path.basename(resume_file_path), "output": parsed_output}, f, ensure_ascii=False, indent=4)

        print(f"Processed {os.path.basename(resume_file_path)}")

    except Exception as e:
        print(f"Error processing {os.path.basename(resume_file_path)}: {e}")

# Multithreading function to process all resumes
def process_all_resumes_multithreaded(resume_directory, output_directory, sys_msg):
    os.makedirs(output_directory, exist_ok=True)
    tasks = []

    for i in range(1000):
        resume_file_path = os.path.join(resume_directory, f"{i}.json")
        
        if not os.path.exists(resume_file_path):
            print(f"Resume file {i}.json not found.")
            continue

        output_file_path = os.path.join(output_directory, f"Processed_Resume_{i}.json")

        if os.path.exists(output_file_path):
            print(f"Already processed Resume {i}. Skipping.")
            continue

        tasks.append((resume_file_path, output_file_path, sys_msg))

    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(process_resume, task[0], task[1], task[2]) for task in tasks]
        concurrent.futures.wait(futures)

    print("All evaluations completed.")

# %%
output_directory = "C:/Users/kesha/coding/c/ShitGettingReal"  # Change to your desired output path
resume_directory = "C:/Users/kesha/coding/c/str_data_resumes/str_data_resumes"

# %%
process_all_resumes_multithreaded(resume_directory, output_directory, sys_msg)
# Out:
# Already processed Resume 0. Skipping.
# Already processed Resume 1. Skipping.
# Already processed Resume 2. Skipping.
# Already processed Resume 3. Skipping.
# Already processed Resume 4. Skipping.
# Already processed Resume 5. Skipping.
# Already processed Resume 6. Skipping.
# Already processed Resume 7. Skipping.
# Already processed Resume 8. Skipping.
# Already processed Resume 9. Skipping.
# Already processed Resume 10. Skipping.
# Already processed Resume 11. Skipping.
# Already processed Resume 12. Skipping.
# Already processed Resume 13. Skipping.
# Already processed Resume 14. Skipping.
# Already processed Resume 15. Skipping.
# Already processed Resume 16. Skipping.
# Already processed Resume 17. Skipping.
# Already processed Resume 18. Skipping.
# Already processed Resume 19. Skipping.
# Already processed Resume 20. Skipping.
# Already processed Resume 21. Skipping.
# Already processed Resume 22. Skipping.
# Already processed Resume 23. Skipping.
# Already processed Resume 24. Skipping.
# Already processed Resume 25. Skipping.
# Already processed Resume 26. Skipping.
# Already processed Resume 27. Skipping.
# Already processed Resume 28. Skipping.
# Already processed Resume 29. Skipping.
# Already processed Resume 30. Skipping.
# Already processed Resume 31. Skipping.
# Already processed Resume 32. Skipping.
# Already processed Resume 33. Skipping.
# Already processed Resume 34. Skipping.
# Already processed Resume 35. Skipping.
# Already processed Resume 36. Skipping.
# Already processed Resume 37. Skipping.
# Already processed Resume 38. Skipping.
# Already processed Resume 39. Skipping.
# Already processed Resume 40. Skipping.
# Already processed Resume 41. Skipping.
# Already processed Resume 42. Skipping.
# Already processed Resume 43. Skipping.
# Already processed Resume 44. Skipping.
# Already processed Resume 45. Skipping.
# Already processed Resume 46. Skipping.
# Already processed Resume 47. Skipping.
# Already processed Resume 48. Skipping.
# Already processed Resume 49. Skipping.
# Already processed Resume 50. Skipping.
# Already processed Resume 51. Skipping.
# Already processed Resume 52. Skipping.
# Already processed Resume 53. Skipping.
# Already processed Resume 54. Skipping.
# Already processed Resume 55. Skipping.
# Already processed Resume 56. Skipping.
# Already processed Resume 57. Skipping.
# Already processed Resume 58. Skipping.
# Already processed Resume 59. Skipping.
# Already processed Resume 60. Skipping.
# Already processed Resume 61. Skipping.
# Already processed Resume 62. Skipping.
# Already processed Resume 63. Skipping.
# Already processed Resume 64. Skipping.
# Already processed Resume 65. Skipping.
# Already processed Resume 66. Skipping.
# Already processed Resume 67. Skipping.
# Already processed Resume 68. Skipping.
# Already processed Resume 69. Skipping.
# Already processed Resume 70. Skipping.
# Already processed Resume 71. Skipping.
# Already processed Resume 72. Skipping.
# Already processed Resume 73. Skipping.
# Already processed Resume 74. Skipping.
# Already processed Resume 75. Skipping.
# Already processed Resume 76. Skipping.
# Already processed Resume 77. Skipping.
# Already processed Resume 78. Skipping.
# Already processed Resume 79. Skipping.
# Already processed Resume 80. Skipping.
# Already processed Resume 81. Skipping.
# Already processed Resume 82. Skipping.
# Already processed Resume 83. Skipping.
# Already processed Resume 84. Skipping.
# Already processed Resume 85. Skipping.
# Already processed Resume 86. Skipping.
# Already processed Resume 87. Skipping.
# Already processed Resume 88. Skipping.
# Already processed Resume 89. Skipping.
# Already processed Resume 90. Skipping.
# Already processed Resume 91. Skipping.
# Already processed Resume 92. Skipping.
# Already processed Resume 93. Skipping.
# Already processed Resume 94. Skipping.
# Already processed Resume 95. Skipping.
# Already processed Resume 96. Skipping.
# Already processed Resume 97. Skipping.
# Already processed Resume 98. Skipping.
# Already processed Resume 99. Skipping.
# Already processed Resume 100. Skipping.
# Already processed Resume 101. Skipping.
# Already processed Resume 102. Skipping.
# Already processed Resume 103. Skipping.
# Already processed Resume 104. Skipping.
# Already processed Resume 105. Skipping.
# Already processed Resume 106. Skipping.
# Already processed Resume 107. Skipping.
# Already processed Resume 108. Skipping.
# Already processed Resume 109. Skipping.
# Already processed Resume 110. Skipping.
# Already processed Resume 111. Skipping.
# Already processed Resume 112. Skipping.
# Already processed Resume 113. Skipping.
# Already processed Resume 114. Skipping.
# Already processed Resume 115. Skipping.
# Already processed Resume 116. Skipping.
# Already processed Resume 117. Skipping.
# Already processed Resume 118. Skipping.
# Already processed Resume 119. Skipping.
# Already processed Resume 120. Skipping.
# Already processed Resume 121. Skipping.
# Already processed Resume 122. Skipping.
# Already processed Resume 123. Skipping.
# Already processed Resume 124. Skipping.
# Already processed Resume 125. Skipping.
# Already processed Resume 126. Skipping.
# Already processed Resume 127. Skipping.
# Already processed Resume 128. Skipping.
# Already processed Resume 129. Skipping.
# Already processed Resume 130. Skipping.
# Already processed Resume 131. Skipping.
# Already processed Resume 132. Skipping.
# Already processed Resume 133. Skipping.
# Already processed Resume 134. Skipping.
# Already processed Resume 135. Skipping.
# Already processed Resume 136. Skipping.
# Already processed Resume 137. Skipping.
# Already processed Resume 138. Skipping.
# Already processed Resume 139. Skipping.
# Already processed Resume 140. Skipping.
# Already processed Resume 141. Skipping.
# Already processed Resume 142. Skipping.
# Already processed Resume 143. Skipping.
# Already processed Resume 144. Skipping.
# Already processed Resume 145. Skipping.
# Already processed Resume 146. Skipping.
# Already processed Resume 147. Skipping.
# Already processed Resume 148. Skipping.
# Already processed Resume 149. Skipping.
# Already processed Resume 150. Skipping.
# Already processed Resume 151. Skipping.
# Already processed Resume 152. Skipping.
# Already processed Resume 153. Skipping.
# Already processed Resume 154. Skipping.
# Already processed Resume 155. Skipping.
# Already processed Resume 156. Skipping.
# Already processed Resume 157. Skipping.
# Already processed Resume 158. Skipping.
# Already processed Resume 159. Skipping.
# Already processed Resume 160. Skipping.
# Already processed Resume 161. Skipping.
# Already processed Resume 162. Skipping.
# Already processed Resume 163. Skipping.
# Already processed Resume 164. Skipping.
# Already processed Resume 165. Skipping.
# Already processed Resume 166. Skipping.
# Already processed Resume 167. Skipping.
# Already processed Resume 168. Skipping.
# Already processed Resume 169. Skipping.
# Already processed Resume 170. Skipping.
# Already processed Resume 171. Skipping.
# Already processed Resume 172. Skipping.
# Already processed Resume 173. Skipping.
# Already processed Resume 174. Skipping.
# Already processed Resume 175. Skipping.
# Already processed Resume 176. Skipping.
# Already processed Resume 177. Skipping.
# Already processed Resume 178. Skipping.
# Already processed Resume 179. Skipping.
# Already processed Resume 180. Skipping.
# Already processed Resume 181. Skipping.
# Already processed Resume 182. Skipping.
# Already processed Resume 183. Skipping.
# Already processed Resume 184. Skipping.
# Already processed Resume 185. Skipping.
# Already processed Resume 186. Skipping.
# Already processed Resume 187. Skipping.
# Already processed Resume 188. Skipping.
# Already processed Resume 189. Skipping.
# Already processed Resume 190. Skipping.
# Already processed Resume 191. Skipping.
# Already processed Resume 192. Skipping.
# Already processed Resume 193. Skipping.
# Already processed Resume 194. Skipping.
# Already processed Resume 195. Skipping.
# Already processed Resume 196. Skipping.
# Already processed Resume 197. Skipping.
# Already processed Resume 198. Skipping.
# Already processed Resume 199. Skipping.
# Already processed Resume 200. Skipping.
# Already processed Resume 201. Skipping.
# Already processed Resume 202. Skipping.
# Already processed Resume 203. Skipping.
# Already processed Resume 204. Skipping.
# Already processed Resume 205. Skipping.
# Already processed Resume 206. Skipping.
# Already processed Resume 207. Skipping.
# Already processed Resume 208. Skipping.
# Already processed Resume 209. Skipping.
# Already processed Resume 210. Skipping.
# Already processed Resume 211. Skipping.
# Already processed Resume 212. Skipping.
# Already processed Resume 213. Skipping.
# Already processed Resume 214. Skipping.
# Already processed Resume 215. Skipping.
# Already processed Resume 216. Skipping.
# Already processed Resume 217. Skipping.
# Already processed Resume 218. Skipping.
# Already processed Resume 219. Skipping.
# Already processed Resume 220. Skipping.
# Already processed Resume 221. Skipping.
# Already processed Resume 222. Skipping.
# Already processed Resume 223. Skipping.
# Already processed Resume 224. Skipping.
# Already processed Resume 225. Skipping.
# Already processed Resume 226. Skipping.
# Already processed Resume 227. Skipping.
# Already processed Resume 228. Skipping.
# Already processed Resume 229. Skipping.
# Already processed Resume 230. Skipping.
# Already processed Resume 231. Skipping.
# Already processed Resume 232. Skipping.
# Already processed Resume 233. Skipping.
# Already processed Resume 234. Skipping.
# Already processed Resume 235. Skipping.
# Already processed Resume 236. Skipping.
# Already processed Resume 237. Skipping.
# Already processed Resume 238. Skipping.
# Already processed Resume 239. Skipping.
# Already processed Resume 240. Skipping.
# Already processed Resume 241. Skipping.
# Already processed Resume 242. Skipping.
# Already processed Resume 243. Skipping.
# Already processed Resume 244. Skipping.
# Already processed Resume 245. Skipping.
# Already processed Resume 246. Skipping.
# Already processed Resume 247. Skipping.
# Already processed Resume 248. Skipping.
# Already processed Resume 249. Skipping.
# Already processed Resume 250. Skipping.
# Already processed Resume 251. Skipping.
# Already processed Resume 252. Skipping.
# Already processed Resume 253. Skipping.
# Already processed Resume 254. Skipping.
# Already processed Resume 255. Skipping.
# Already processed Resume 256. Skipping.
# Already processed Resume 257. Skipping.
# Already processed Resume 258. Skipping.
# Already processed Resume 259. Skipping.
# Already processed Resume 260. Skipping.
# Already processed Resume 261. Skipping.
# Already processed Resume 262. Skipping.
# Already processed Resume 263. Skipping.
# Already processed Resume 264. Skipping.
# Already processed Resume 265. Skipping.
# Already processed Resume 266. Skipping.
# Already processed Resume 267. Skipping.
# Already processed Resume 268. Skipping.
# Already processed Resume 269. Skipping.
# Already processed Resume 270. Skipping.
# Already processed Resume 271. Skipping.
# Already processed Resume 272. Skipping.
# Already processed Resume 273. Skipping.
# Already processed Resume 274. Skipping.
# Already processed Resume 275. Skipping.
# Already processed Resume 276. Skipping.
# Already processed Resume 277. Skipping.
# Already processed Resume 278. Skipping.
# Already processed Resume 279. Skipping.
# Already processed Resume 280. Skipping.
# Already processed Resume 281. Skipping.
# Already processed Resume 282. Skipping.
# Already processed Resume 283. Skipping.
# Already processed Resume 284. Skipping.
# Already processed Resume 285. Skipping.
# Already processed Resume 286. Skipping.
# Already processed Resume 287. Skipping.
# Already processed Resume 288. Skipping.
# Already processed Resume 289. Skipping.
# Already processed Resume 290. Skipping.
# Already processed Resume 291. Skipping.
# Already processed Resume 292. Skipping.
# Already processed Resume 293. Skipping.
# Already processed Resume 294. Skipping.
# Already processed Resume 295. Skipping.
# Already processed Resume 296. Skipping.
# Already processed Resume 297. Skipping.
# Already processed Resume 298. Skipping.
# Already processed Resume 299. Skipping.
# Already processed Resume 300. Skipping.
# Already processed Resume 301. Skipping.
# Already processed Resume 302. Skipping.
# Already processed Resume 303. Skipping.
# Already processed Resume 304. Skipping.
# Already processed Resume 305. Skipping.
# Already processed Resume 306. Skipping.
# Already processed Resume 307. Skipping.
# Already processed Resume 308. Skipping.
# Already processed Resume 309. Skipping.
# Already processed Resume 310. Skipping.
# Already processed Resume 311. Skipping.
# Already processed Resume 312. Skipping.
# Already processed Resume 313. Skipping.
# Already processed Resume 314. Skipping.
# Already processed Resume 315. Skipping.
# Already processed Resume 316. Skipping.
# Already processed Resume 317. Skipping.
# Already processed Resume 318. Skipping.
# Already processed Resume 319. Skipping.
# Already processed Resume 320. Skipping.
# Already processed Resume 321. Skipping.
# Already processed Resume 322. Skipping.
# Already processed Resume 323. Skipping.
# Already processed Resume 324. Skipping.
# Already processed Resume 325. Skipping.
# Already processed Resume 326. Skipping.
# Already processed Resume 327. Skipping.
# Already processed Resume 328. Skipping.
# Already processed Resume 329. Skipping.
# Already processed Resume 330. Skipping.
# Already processed Resume 331. Skipping.
# Already processed Resume 332. Skipping.
# Already processed Resume 333. Skipping.
# Already processed Resume 334. Skipping.
# Already processed Resume 335. Skipping.
# Already processed Resume 336. Skipping.
# Already processed Resume 337. Skipping.
# Already processed Resume 338. Skipping.
# Already processed Resume 339. Skipping.
# Already processed Resume 340. Skipping.
# Already processed Resume 341. Skipping.
# Already processed Resume 342. Skipping.
# Already processed Resume 343. Skipping.
# Already processed Resume 344. Skipping.
# Already processed Resume 345. Skipping.
# Already processed Resume 346. Skipping.
# Already processed Resume 347. Skipping.
# Already processed Resume 348. Skipping.
# Already processed Resume 349. Skipping.
# Already processed Resume 350. Skipping.
# Already processed Resume 351. Skipping.
# Already processed Resume 352. Skipping.
# Already processed Resume 353. Skipping.
# Already processed Resume 354. Skipping.
# Already processed Resume 355. Skipping.
# Already processed Resume 356. Skipping.
# Already processed Resume 357. Skipping.
# Already processed Resume 358. Skipping.
# Already processed Resume 359. Skipping.
# Already processed Resume 360. Skipping.
# Already processed Resume 361. Skipping.
# Already processed Resume 362. Skipping.
# Already processed Resume 363. Skipping.
# Already processed Resume 364. Skipping.
# Already processed Resume 365. Skipping.
# Already processed Resume 366. Skipping.
# Already processed Resume 367. Skipping.
# Already processed Resume 368. Skipping.
# Already processed Resume 369. Skipping.
# Already processed Resume 370. Skipping.
# Already processed Resume 371. Skipping.
# Already processed Resume 372. Skipping.
# Already processed Resume 373. Skipping.
# Already processed Resume 374. Skipping.
# Already processed Resume 375. Skipping.
# Already processed Resume 376. Skipping.
# Already processed Resume 377. Skipping.
# Already processed Resume 378. Skipping.
# Already processed Resume 379. Skipping.
# Already processed Resume 380. Skipping.
# Already processed Resume 381. Skipping.
# Already processed Resume 382. Skipping.
# Already processed Resume 383. Skipping.
# Already processed Resume 384. Skipping.
# Already processed Resume 385. Skipping.
# Already processed Resume 386. Skipping.
# Already processed Resume 387. Skipping.
# Already processed Resume 388. Skipping.
# Already processed Resume 389. Skipping.
# Already processed Resume 390. Skipping.
# Already processed Resume 391. Skipping.
# Already processed Resume 393. Skipping.
# Already processed Resume 394. Skipping.
# Already processed Resume 395. Skipping.
# Already processed Resume 396. Skipping.
# Already processed Resume 397. Skipping.
# Already processed Resume 398. Skipping.
# Already processed Resume 399. Skipping.
# Already processed Resume 400. Skipping.
# Already processed Resume 401. Skipping.
# Already processed Resume 402. Skipping.
# Already processed Resume 403. Skipping.
# Already processed Resume 404. Skipping.
# Already processed Resume 405. Skipping.
# Already processed Resume 406. Skipping.
# Already processed Resume 407. Skipping.
# Already processed Resume 408. Skipping.
# Already processed Resume 409. Skipping.
# Already processed Resume 410. Skipping.
# Already processed Resume 411. Skipping.
# Already processed Resume 412. Skipping.
# Already processed Resume 413. Skipping.
# Already processed Resume 414. Skipping.
# Already processed Resume 415. Skipping.
# Already processed Resume 416. Skipping.
# Already processed Resume 417. Skipping.
# Already processed Resume 418. Skipping.
# Already processed Resume 419. Skipping.
# Already processed Resume 420. Skipping.
# Already processed Resume 421. Skipping.
# Already processed Resume 422. Skipping.
# Already processed Resume 423. Skipping.
# Already processed Resume 424. Skipping.
# Already processed Resume 425. Skipping.
# Already processed Resume 426. Skipping.
# Already processed Resume 427. Skipping.
# Already processed Resume 428. Skipping.
# Already processed Resume 429. Skipping.
# Already processed Resume 430. Skipping.
# Already processed Resume 431. Skipping.
# Already processed Resume 432. Skipping.
# Already processed Resume 433. Skipping.
# Already processed Resume 434. Skipping.
# Already processed Resume 435. Skipping.
# Already processed Resume 436. Skipping.
# Already processed Resume 437. Skipping.
# Already processed Resume 438. Skipping.
# Already processed Resume 439. Skipping.
# Already processed Resume 440. Skipping.
# Already processed Resume 441. Skipping.
# Already processed Resume 442. Skipping.
# Already processed Resume 443. Skipping.
# Already processed Resume 444. Skipping.
# Already processed Resume 445. Skipping.
# Already processed Resume 446. Skipping.
# Already processed Resume 447. Skipping.
# Already processed Resume 448. Skipping.
# Already processed Resume 449. Skipping.
# Already processed Resume 450. Skipping.
# Already processed Resume 451. Skipping.
# Already processed Resume 452. Skipping.
# Already processed Resume 453. Skipping.
# Already processed Resume 454. Skipping.
# Already processed Resume 455. Skipping.
# Already processed Resume 456. Skipping.
# Already processed Resume 457. Skipping.
# Already processed Resume 458. Skipping.
# Already processed Resume 459. Skipping.
# Already processed Resume 460. Skipping.
# Already processed Resume 461. Skipping.
# Already processed Resume 462. Skipping.
# Already processed Resume 463. Skipping.
# Already processed Resume 464. Skipping.
# Already processed Resume 465. Skipping.
# Already processed Resume 466. Skipping.
# Already processed Resume 467. Skipping.
# Already processed Resume 468. Skipping.
# Already processed Resume 469. Skipping.
# Already processed Resume 470. Skipping.
# Already processed Resume 471. Skipping.
# Already processed Resume 472. Skipping.
# Already processed Resume 473. Skipping.
# Already processed Resume 474. Skipping.
# Already processed Resume 475. Skipping.
# Already processed Resume 476. Skipping.
# Already processed Resume 477. Skipping.
# Already processed Resume 478. Skipping.
# Already processed Resume 479. Skipping.
# Already processed Resume 480. Skipping.
# Already processed Resume 481. Skipping.
# Already processed Resume 482. Skipping.
# Already processed Resume 483. Skipping.
# Already processed Resume 484. Skipping.
# Already processed Resume 485. Skipping.
# Already processed Resume 486. Skipping.
# Already processed Resume 487. Skipping.
# Already processed Resume 488. Skipping.
# Already processed Resume 489. Skipping.
# Already processed Resume 490. Skipping.
# Already processed Resume 491. Skipping.
# Already processed Resume 492. Skipping.
# Already processed Resume 493. Skipping.
# Already processed Resume 494. Skipping.
# Already processed Resume 495. Skipping.
# Already processed Resume 496. Skipping.
# Already processed Resume 497. Skipping.
# Already processed Resume 498. Skipping.
# Already processed Resume 499. Skipping.
# Already processed Resume 500. Skipping.
# Already processed Resume 501. Skipping.
# Already processed Resume 502. Skipping.
# Already processed Resume 503. Skipping.
# Already processed Resume 504. Skipping.
# Already processed Resume 505. Skipping.
# Already processed Resume 506. Skipping.
# Already processed Resume 507. Skipping.
# Already processed Resume 508. Skipping.
# Already processed Resume 509. Skipping.
# Already processed Resume 510. Skipping.
# Already processed Resume 511. Skipping.
# Already processed Resume 512. Skipping.
# Already processed Resume 513. Skipping.
# Already processed Resume 514. Skipping.
# Already processed Resume 515. Skipping.
# Already processed Resume 516. Skipping.
# Already processed Resume 517. Skipping.
# Already processed Resume 518. Skipping.
# Already processed Resume 519. Skipping.
# Already processed Resume 520. Skipping.
# Already processed Resume 521. Skipping.
# Already processed Resume 522. Skipping.
# Already processed Resume 523. Skipping.
# Already processed Resume 524. Skipping.
# Already processed Resume 525. Skipping.
# Already processed Resume 526. Skipping.
# Already processed Resume 527. Skipping.
# Already processed Resume 528. Skipping.
# Already processed Resume 529. Skipping.
# Already processed Resume 530. Skipping.
# Already processed Resume 531. Skipping.
# Already processed Resume 532. Skipping.
# Already processed Resume 533. Skipping.
# Already processed Resume 534. Skipping.
# Already processed Resume 535. Skipping.
# Already processed Resume 536. Skipping.
# Already processed Resume 537. Skipping.
# Already processed Resume 538. Skipping.
# Already processed Resume 539. Skipping.
# Already processed Resume 540. Skipping.
# Already processed Resume 541. Skipping.
# Already processed Resume 542. Skipping.
# Already processed Resume 543. Skipping.
# Already processed Resume 544. Skipping.
# Already processed Resume 545. Skipping.
# Already processed Resume 546. Skipping.
# Already processed Resume 547. Skipping.
# Already processed Resume 548. Skipping.
# Already processed Resume 549. Skipping.
# Already processed Resume 550. Skipping.
# Already processed Resume 551. Skipping.
# Already processed Resume 552. Skipping.
# Already processed Resume 553. Skipping.
# Already processed Resume 554. Skipping.
# Already processed Resume 555. Skipping.
# Already processed Resume 556. Skipping.
# Already processed Resume 557. Skipping.
# Already processed Resume 558. Skipping.
# Already processed Resume 559. Skipping.
# Already processed Resume 560. Skipping.
# Already processed Resume 561. Skipping.
# Already processed Resume 562. Skipping.
# Already processed Resume 563. Skipping.
# Already processed Resume 564. Skipping.
# Already processed Resume 565. Skipping.
# Already processed Resume 566. Skipping.
# Already processed Resume 567. Skipping.
# Already processed Resume 568. Skipping.
# Already processed Resume 569. Skipping.
# Already processed Resume 570. Skipping.
# Already processed Resume 571. Skipping.
# Already processed Resume 572. Skipping.
# Already processed Resume 573. Skipping.
# Already processed Resume 574. Skipping.
# Already processed Resume 575. Skipping.
# Already processed Resume 576. Skipping.
# Already processed Resume 577. Skipping.
# Already processed Resume 578. Skipping.
# Already processed Resume 579. Skipping.
# Already processed Resume 580. Skipping.
# Already processed Resume 581. Skipping.
# Already processed Resume 582. Skipping.
# Already processed Resume 583. Skipping.
# Already processed Resume 584. Skipping.
# Already processed Resume 585. Skipping.
# Already processed Resume 586. Skipping.
# Already processed Resume 587. Skipping.
# Already processed Resume 588. Skipping.
# Already processed Resume 589. Skipping.
# Already processed Resume 590. Skipping.
# Already processed Resume 591. Skipping.
# Already processed Resume 592. Skipping.
# Already processed Resume 593. Skipping.
# Already processed Resume 594. Skipping.
# Already processed Resume 595. Skipping.
# Already processed Resume 596. Skipping.
# Already processed Resume 597. Skipping.
# Already processed Resume 598. Skipping.
# Already processed Resume 599. Skipping.
# Already processed Resume 600. Skipping.
# Already processed Resume 601. Skipping.
# Already processed Resume 602. Skipping.
# Already processed Resume 603. Skipping.
# Already processed Resume 604. Skipping.
# Already processed Resume 605. Skipping.
# Already processed Resume 606. Skipping.
# Already processed Resume 607. Skipping.
# Already processed Resume 608. Skipping.
# Already processed Resume 609. Skipping.
# Already processed Resume 610. Skipping.
# Already processed Resume 611. Skipping.
# Already processed Resume 612. Skipping.
# Already processed Resume 613. Skipping.
# Already processed Resume 614. Skipping.
# Already processed Resume 615. Skipping.
# Already processed Resume 616. Skipping.
# Already processed Resume 617. Skipping.
# Already processed Resume 618. Skipping.
# Already processed Resume 619. Skipping.
# Already processed Resume 620. Skipping.
# Already processed Resume 621. Skipping.
# Already processed Resume 622. Skipping.
# Already processed Resume 623. Skipping.
# Already processed Resume 624. Skipping.
# Already processed Resume 625. Skipping.
# Already processed Resume 626. Skipping.
# Already processed Resume 627. Skipping.
# Already processed Resume 628. Skipping.
# Already processed Resume 629. Skipping.
# Already processed Resume 630. Skipping.
# Already processed Resume 631. Skipping.
# Already processed Resume 632. Skipping.
# Already processed Resume 633. Skipping.
# Already processed Resume 634. Skipping.
# Already processed Resume 635. Skipping.
# Already processed Resume 636. Skipping.
# Already processed Resume 637. Skipping.
# Already processed Resume 638. Skipping.
# Already processed Resume 639. Skipping.
# Already processed Resume 640. Skipping.
# Already processed Resume 641. Skipping.
# Already processed Resume 642. Skipping.
# Already processed Resume 643. Skipping.
# Already processed Resume 644. Skipping.
# Already processed Resume 645. Skipping.
# Already processed Resume 646. Skipping.
# Already processed Resume 647. Skipping.
# Already processed Resume 648. Skipping.
# Already processed Resume 649. Skipping.
# Already processed Resume 650. Skipping.
# Already processed Resume 651. Skipping.
# Already processed Resume 652. Skipping.
# Already processed Resume 653. Skipping.
# Already processed Resume 654. Skipping.
# Already processed Resume 655. Skipping.
# Already processed Resume 656. Skipping.
# Already processed Resume 657. Skipping.
# Already processed Resume 658. Skipping.
# Already processed Resume 659. Skipping.
# Already processed Resume 660. Skipping.
# Already processed Resume 661. Skipping.
# Already processed Resume 662. Skipping.
# Already processed Resume 663. Skipping.
# Already processed Resume 664. Skipping.
# Already processed Resume 665. Skipping.
# Already processed Resume 666. Skipping.
# Already processed Resume 667. Skipping.
# Already processed Resume 668. Skipping.
# Already processed Resume 669. Skipping.
# Already processed Resume 670. Skipping.
# Already processed Resume 671. Skipping.
# Already processed Resume 672. Skipping.
# Already processed Resume 673. Skipping.
# Already processed Resume 674. Skipping.
# Already processed Resume 675. Skipping.
# Already processed Resume 676. Skipping.
# Already processed Resume 677. Skipping.
# Already processed Resume 678. Skipping.
# Already processed Resume 679. Skipping.
# Already processed Resume 680. Skipping.
# Already processed Resume 681. Skipping.
# Already processed Resume 682. Skipping.
# Already processed Resume 683. Skipping.
# Already processed Resume 684. Skipping.
# Already processed Resume 685. Skipping.
# Already processed Resume 686. Skipping.
# Already processed Resume 687. Skipping.
# Already processed Resume 688. Skipping.
# Already processed Resume 689. Skipping.
# Already processed Resume 690. Skipping.
# Already processed Resume 691. Skipping.
# Already processed Resume 692. Skipping.
# Already processed Resume 693. Skipping.
# Already processed Resume 694. Skipping.
# Already processed Resume 695. Skipping.
# Already processed Resume 696. Skipping.
# Already processed Resume 697. Skipping.
# Already processed Resume 698. Skipping.
# Already processed Resume 699. Skipping.
# Already processed Resume 700. Skipping.
# Already processed Resume 701. Skipping.
# Already processed Resume 702. Skipping.
# Already processed Resume 703. Skipping.
# Already processed Resume 704. Skipping.
# Already processed Resume 705. Skipping.
# Already processed Resume 706. Skipping.
# Already processed Resume 707. Skipping.
# Already processed Resume 708. Skipping.
# Already processed Resume 709. Skipping.
# Already processed Resume 710. Skipping.
# Already processed Resume 711. Skipping.
# Already processed Resume 712. Skipping.
# Already processed Resume 713. Skipping.
# Already processed Resume 714. Skipping.
# Already processed Resume 715. Skipping.
# Already processed Resume 716. Skipping.
# Already processed Resume 717. Skipping.
# Already processed Resume 718. Skipping.
# Already processed Resume 719. Skipping.
# Already processed Resume 720. Skipping.
# Already processed Resume 721. Skipping.
# Already processed Resume 722. Skipping.
# Already processed Resume 723. Skipping.
# Already processed Resume 724. Skipping.
# Already processed Resume 725. Skipping.
# Already processed Resume 726. Skipping.
# Already processed Resume 727. Skipping.
# Already processed Resume 728. Skipping.
# Already processed Resume 729. Skipping.
# Already processed Resume 730. Skipping.
# Already processed Resume 731. Skipping.
# Already processed Resume 732. Skipping.
# Already processed Resume 733. Skipping.
# Already processed Resume 734. Skipping.
# Already processed Resume 735. Skipping.
# Already processed Resume 736. Skipping.
# Already processed Resume 737. Skipping.
# Already processed Resume 738. Skipping.
# Already processed Resume 739. Skipping.
# Already processed Resume 740. Skipping.
# Already processed Resume 741. Skipping.
# Already processed Resume 742. Skipping.
# Already processed Resume 743. Skipping.
# Already processed Resume 744. Skipping.
# Already processed Resume 745. Skipping.
# Already processed Resume 746. Skipping.
# Already processed Resume 747. Skipping.
# Already processed Resume 748. Skipping.
# Already processed Resume 749. Skipping.
# Already processed Resume 750. Skipping.
# Already processed Resume 751. Skipping.
# Already processed Resume 752. Skipping.
# Already processed Resume 753. Skipping.
# Already processed Resume 754. Skipping.
# Already processed Resume 755. Skipping.
# Already processed Resume 756. Skipping.
# Already processed Resume 757. Skipping.
# Already processed Resume 758. Skipping.
# Already processed Resume 759. Skipping.
# Already processed Resume 760. Skipping.
# Already processed Resume 761. Skipping.
# Already processed Resume 762. Skipping.
# Already processed Resume 763. Skipping.
# Already processed Resume 764. Skipping.
# Already processed Resume 765. Skipping.
# Already processed Resume 766. Skipping.
# Already processed Resume 767. Skipping.
# Already processed Resume 768. Skipping.
# Already processed Resume 769. Skipping.
# Already processed Resume 770. Skipping.
# Already processed Resume 771. Skipping.
# Already processed Resume 772. Skipping.
# Already processed Resume 773. Skipping.
# Already processed Resume 774. Skipping.
# Already processed Resume 775. Skipping.
# Already processed Resume 776. Skipping.
# Already processed Resume 777. Skipping.
# Already processed Resume 778. Skipping.
# Already processed Resume 779. Skipping.
# Already processed Resume 780. Skipping.
# Already processed Resume 781. Skipping.
# Already processed Resume 782. Skipping.
# Already processed Resume 783. Skipping.
# Already processed Resume 784. Skipping.
# Already processed Resume 785. Skipping.
# Already processed Resume 786. Skipping.
# Already processed Resume 787. Skipping.
# Already processed Resume 788. Skipping.
# Already processed Resume 789. Skipping.
# Already processed Resume 790. Skipping.
# Already processed Resume 791. Skipping.
# Already processed Resume 792. Skipping.
# Already processed Resume 793. Skipping.
# Already processed Resume 794. Skipping.
# Already processed Resume 795. Skipping.
# Already processed Resume 796. Skipping.
# Already processed Resume 797. Skipping.
# Already processed Resume 798. Skipping.
# Already processed Resume 799. Skipping.
# Already processed Resume 800. Skipping.
# Already processed Resume 801. Skipping.
# Already processed Resume 802. Skipping.
# Already processed Resume 803. Skipping.
# Already processed Resume 804. Skipping.
# Already processed Resume 805. Skipping.
# Already processed Resume 806. Skipping.
# Already processed Resume 807. Skipping.
# Already processed Resume 808. Skipping.
# Already processed Resume 809. Skipping.
# Already processed Resume 810. Skipping.
# Already processed Resume 811. Skipping.
# Already processed Resume 812. Skipping.
# Already processed Resume 813. Skipping.
# Already processed Resume 814. Skipping.
# Already processed Resume 815. Skipping.
# Already processed Resume 816. Skipping.
# Already processed Resume 817. Skipping.
# Already processed Resume 818. Skipping.
# Already processed Resume 819. Skipping.
# Already processed Resume 820. Skipping.
# Already processed Resume 821. Skipping.
# Already processed Resume 822. Skipping.
# Already processed Resume 823. Skipping.
# Already processed Resume 824. Skipping.
# Already processed Resume 825. Skipping.
# Already processed Resume 826. Skipping.
# Already processed Resume 827. Skipping.
# Already processed Resume 828. Skipping.
# Already processed Resume 829. Skipping.
# Already processed Resume 830. Skipping.
# Already processed Resume 831. Skipping.
# Already processed Resume 832. Skipping.
# Already processed Resume 833. Skipping.
# Already processed Resume 834. Skipping.
# Already processed Resume 835. Skipping.
# Already processed Resume 836. Skipping.
# Already processed Resume 837. Skipping.
# Already processed Resume 838. Skipping.
# Already processed Resume 839. Skipping.
# Already processed Resume 840. Skipping.
# Already processed Resume 841. Skipping.
# Already processed Resume 842. Skipping.
# Already processed Resume 843. Skipping.
# Already processed Resume 844. Skipping.
# Already processed Resume 845. Skipping.
# Already processed Resume 846. Skipping.
# Already processed Resume 847. Skipping.
# Already processed Resume 848. Skipping.
# Already processed Resume 849. Skipping.
# Already processed Resume 850. Skipping.
# Already processed Resume 851. Skipping.
# Already processed Resume 852. Skipping.
# Already processed Resume 853. Skipping.
# Already processed Resume 854. Skipping.
# Already processed Resume 855. Skipping.
# Already processed Resume 856. Skipping.
# Already processed Resume 857. Skipping.
# Already processed Resume 858. Skipping.
# Already processed Resume 859. Skipping.
# Already processed Resume 860. Skipping.
# Already processed Resume 861. Skipping.
# Already processed Resume 862. Skipping.
# Already processed Resume 863. Skipping.
# Already processed Resume 864. Skipping.
# Already processed Resume 865. Skipping.
# Already processed Resume 866. Skipping.
# Already processed Resume 867. Skipping.
# Already processed Resume 868. Skipping.
# Already processed Resume 869. Skipping.
# Already processed Resume 870. Skipping.
# Already processed Resume 871. Skipping.
# Already processed Resume 872. Skipping.
# Already processed Resume 873. Skipping.
# Already processed Resume 874. Skipping.
# Already processed Resume 875. Skipping.
# Already processed Resume 876. Skipping.
# Already processed Resume 877. Skipping.
# Already processed Resume 878. Skipping.
# Already processed Resume 879. Skipping.
# Already processed Resume 880. Skipping.
# Already processed Resume 881. Skipping.
# Already processed Resume 882. Skipping.
# Already processed Resume 883. Skipping.
# Already processed Resume 884. Skipping.
# Already processed Resume 885. Skipping.
# Already processed Resume 886. Skipping.
# Already processed Resume 887. Skipping.
# Already processed Resume 888. Skipping.
# Already processed Resume 889. Skipping.
# Already processed Resume 890. Skipping.
# Already processed Resume 891. Skipping.
# Already processed Resume 892. Skipping.
# Already processed Resume 893. Skipping.
# Already processed Resume 894. Skipping.
# Already processed Resume 895. Skipping.
# Already processed Resume 896. Skipping.
# Already processed Resume 897. Skipping.
# Already processed Resume 898. Skipping.
# Already processed Resume 899. Skipping.
# Already processed Resume 900. Skipping.
# Already processed Resume 901. Skipping.
# Already processed Resume 902. Skipping.
# Already processed Resume 903. Skipping.
# Already processed Resume 904. Skipping.
# Already processed Resume 905. Skipping.
# Already processed Resume 906. Skipping.
# Already processed Resume 907. Skipping.
# Already processed Resume 908. Skipping.
# Already processed Resume 909. Skipping.
# Already processed Resume 910. Skipping.
# Already processed Resume 911. Skipping.
# Already processed Resume 912. Skipping.
# Already processed Resume 913. Skipping.
# Already processed Resume 914. Skipping.
# Already processed Resume 915. Skipping.
# Already processed Resume 916. Skipping.
# Already processed Resume 917. Skipping.
# Already processed Resume 918. Skipping.
# Already processed Resume 919. Skipping.
# Already processed Resume 920. Skipping.
# Already processed Resume 921. Skipping.
# Already processed Resume 922. Skipping.
# Already processed Resume 923. Skipping.
# Already processed Resume 924. Skipping.
# Already processed Resume 925. Skipping.
# Already processed Resume 926. Skipping.
# Already processed Resume 927. Skipping.
# Already processed Resume 928. Skipping.
# Already processed Resume 929. Skipping.
# Already processed Resume 930. Skipping.
# Already processed Resume 931. Skipping.
# Already processed Resume 932. Skipping.
# Already processed Resume 933. Skipping.
# Already processed Resume 934. Skipping.
# Already processed Resume 935. Skipping.
# Already processed Resume 936. Skipping.
# Already processed Resume 937. Skipping.
# Already processed Resume 938. Skipping.
# Already processed Resume 939. Skipping.
# Already processed Resume 940. Skipping.
# Already processed Resume 941. Skipping.
# Already processed Resume 942. Skipping.
# Already processed Resume 943. Skipping.
# Already processed Resume 944. Skipping.
# Already processed Resume 945. Skipping.
# Already processed Resume 946. Skipping.
# Already processed Resume 947. Skipping.
# Already processed Resume 948. Skipping.
# Already processed Resume 949. Skipping.
# Already processed Resume 950. Skipping.
# Already processed Resume 951. Skipping.
# Already processed Resume 952. Skipping.
# Already processed Resume 953. Skipping.
# Already processed Resume 954. Skipping.
# Already processed Resume 955. Skipping.
# Already processed Resume 956. Skipping.
# Already processed Resume 957. Skipping.
# Already processed Resume 958. Skipping.
# Already processed Resume 959. Skipping.
# Already processed Resume 960. Skipping.
# Already processed Resume 961. Skipping.
# Already processed Resume 962. Skipping.
# Already processed Resume 963. Skipping.
# Already processed Resume 964. Skipping.
# Already processed Resume 965. Skipping.
# Already processed Resume 966. Skipping.
# Already processed Resume 967. Skipping.
# Already processed Resume 968. Skipping.
# Already processed Resume 969. Skipping.
# Already processed Resume 970. Skipping.
# Already processed Resume 971. Skipping.
# Already processed Resume 972. Skipping.
# Already processed Resume 973. Skipping.
# Already processed Resume 974. Skipping.
# Already processed Resume 975. Skipping.
# Already processed Resume 976. Skipping.
# Already processed Resume 977. Skipping.
# Already processed Resume 978. Skipping.
# Already processed Resume 979. Skipping.
# Already processed Resume 980. Skipping.
# Already processed Resume 981. Skipping.
# Already processed Resume 982. Skipping.
# Already processed Resume 983. Skipping.
# Already processed Resume 984. Skipping.
# Already processed Resume 985. Skipping.
# Already processed Resume 986. Skipping.
# Already processed Resume 987. Skipping.
# Already processed Resume 988. Skipping.
# Already processed Resume 989. Skipping.
# Already processed Resume 990. Skipping.
# Already processed Resume 991. Skipping.
# Already processed Resume 992. Skipping.
# Already processed Resume 993. Skipping.
# Already processed Resume 994. Skipping.
# Already processed Resume 995. Skipping.
# Already processed Resume 996. Skipping.
# Already processed Resume 997. Skipping.
# Already processed Resume 998. Skipping.
# Already processed Resume 999. Skipping.
# Processed 392.json
# All evaluations completed.
